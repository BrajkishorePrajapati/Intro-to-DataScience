# %% [markdown]
# # **Some useful methods in Data Pre-processing.**

# %% [markdown]
# # **Merging DataFrame**

# %%
import numpy as np 
import pandas as pd

# %%
# Create a dataframe.
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')

# Create another dataframe.
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')
print(staff_df.head())
print()
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
# Set index for staff_df
staff_df =pd.DataFrame({'Name':['kelly','sally','james'],
                       'Role':['Director of HR','Course liasion','Grader']})
staff_df= staff_df.set_index('Name')
print(staff_df)
# Out:
#                  Role
# Name
# kelly  Director of HR
# sally  Course liasion
# james          Grader

# %%
# set index for student_df.
student_df = pd.DataFrame({'Name':['james','mike','sally'],
                          'Role':['Business','Law','Engineering']})
student_df= student_df.set_index('Name')
print(student_df)
# Out:
#               Role
# Name
# james     Business
# mike           Law
# sally  Engineering

# %% [markdown]
# **Merging when index is set**

# %% [markdown]
# ## **Outer join -**
# Is used to find the union of two dataframe.**

# %%
pd.merge(staff_df,student_df, how ='outer', left_index =True, right_index= True) #outer join is used to find union of two dataframe
# Out:
#                Role_x       Role_y
# Name
# james          Grader     Business
# kelly  Director of HR          NaN
# mike              NaN          Law
# sally  Course liasion  Engineering

# %% [markdown]
# #Inner join
# Is used to find intersection of two dataframe.

# %%
pd.merge(staff_df,student_df, how = 'inner', left_index = True, right_index=True) #inner join is used to find intersection of two dataframe.
# Out:
#                Role_x       Role_y
# Name
# sally  Course liasion  Engineering
# james          Grader     Business

# %% [markdown]
# #Left join
# Is used to display all attribute left most DataFrame like in his staff_df is left dataFrame.

# %%
pd.merge(staff_df,student_df, how= 'left', left_index = True, right_index = True) #left join is used to display all attribute left most DataFrame like in his staff_df is left dataFrame.
# Out:
#                Role_x       Role_y
# Name
# kelly  Director of HR          NaN
# sally  Course liasion  Engineering
# james          Grader     Business

# %% [markdown]
# #Right join
# Is used to display all attribute right most DataFrame like in his student_df is right dataFrame.

# %%
pd.merge(staff_df,student_df, how= 'right', left_index = True, right_index = True) #right join is used to display all attribute right most DataFrame like in his student_df is right dataFrame.
# Out:
#                Role_x       Role_y
# Name
# james          Grader     Business
# mike              NaN          Law
# sally  Course liasion  Engineering

# %% [markdown]
# **Merging when index is not set.**

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#    index_x   Name          Role_x  index_y       Role_y
# 0        0  kelly  Director of HR      NaN          NaN
# 1        1  sally  Course liasion      2.0  Engineering
# 2        2  james          Grader      0.0     Business

# %%
staff_df =pd.DataFrame({'Name':['kelly','sally','james'],
                       'Role':['Director of HR','Course liasion','Grader'],
                       'Location':['Agra','Gwaior','Gwalior']})
staff_df
# Out:
#     Name            Role Location
# 0  kelly  Director of HR     Agra
# 1  sally  Course liasion   Gwaior
# 2  james          Grader  Gwalior

# %%
student_df = pd.DataFrame({'Name':['james','mike','sally'],
                          'Role':['Business','Law','Engineering'],
                          'Location':['Mumbai','Bhopal','Indore']})
student_df
# Out:
#     Name         Role Location
# 0  james     Business   Mumbai
# 1   mike          Law   Bhopal
# 2  sally  Engineering   Indore

# %%
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name          Role_x Location  index       Role_y
# 0  kelly  Director of HR     Agra    NaN          NaN
# 1  sally  Course liasion   Gwaior    2.0  Engineering
# 2  james          Grader  Gwalior    0.0     Business

# %%
staff_df =pd.DataFrame({'First Name':['kelly','sally','james'],
                       'Role':['Director of HR','Course liasion','Grader'],
                       'Last Name':['desjardins','brooks','wilde']})
staff_df
# Out:
#   First Name            Role   Last Name
# 0      kelly  Director of HR  desjardins
# 1      sally  Course liasion      brooks
# 2      james          Grader       wilde

# %%
student_df = pd.DataFrame({'First Name':['james','mike','sally'],
                          'Role':['Business','Law','Engineering'],
                          'Last Name':['hammond','smith','brooks']})
student_df
# Out:
#   First Name         Role Last Name
# 0      james     Business   hammond
# 1       mike          Law     smith
# 2      sally  Engineering    brooks

# %%
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name']) # in this we get whose first nameas well last name is common.
# Out:
#   First Name          Role_x Last Name       Role_y
# 0      sally  Course liasion    brooks  Engineering

# %% [markdown]
# # **                                                                                                      Pandas Idioms**
#
# > Indented block

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Data science/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 0      40       3         6  ...     1.383282     1.724718    0.712594
# 1      50       3         6  ...    -2.722002     2.592270   -2.187333
# 2      50       3         6  ...    22.727626    20.317142   18.293499
# 3      50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4      50       3         6  ...    -5.403729     0.754533    1.107861
#
# [5 rows x 100 columns]

# %% [markdown]
# **Method chaning** is a technique that is used for making method calls on the same object,using the object reference just once.

# %%
(df.where(df['SUMLEV']==50)     # Method chaning is a technique that is used for making method calls on the same object,using the object reference just once.
 .dropna()
 .set_index(['STNAME','CTYNAME'])
 .rename(columns={'CENSUS2010POP':'CENSUS 2010 POP'}).head())
# Out:
#                         SUMLEV  REGION  ...  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME                         ...
# Alabama Autauga County    50.0     3.0  ...     2.592270    -2.187333
#         Baldwin County    50.0     3.0  ...    20.317142    18.293499
#         Barbour County    50.0     3.0  ...    -3.978583   -10.543299
#         Bibb County       50.0     3.0  ...     0.754533     1.107861
#         Blount County     50.0     3.0  ...    -1.577232    -0.884411
#
# [5 rows x 98 columns]

# %%
df= df[df['SUMLEV']==50]               # General method
df.set_index(['STNAME','CTYNAME'],inplace =True)
df.rename(columns={'CENSUS2010POP':'CENSUS 2010 POP'})
# Out:
#                            SUMLEV  REGION  ...  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME                            ...
# Alabama Autauga County         50       3  ...     2.592270    -2.187333
#         Baldwin County         50       3  ...    20.317142    18.293499
#         Barbour County         50       3  ...    -3.978583   -10.543299
#         Bibb County            50       3  ...     0.754533     1.107861
#         Blount County          50       3  ...    -1.577232    -0.884411
# ...                           ...     ...  ...          ...          ...
# Wyoming Sweetwater County      50       4  ...   -14.075283   -14.070195
#         Teton County           50       4  ...    16.308671     1.520747
#         Uinta County           50       4  ...   -14.740608   -12.606351
#         Washakie County        50       4  ...   -18.020168     1.441961
#         Weston County          50       4  ...     1.533635     6.935294
#
# [3142 rows x 98 columns]

# %%
df.head()
# Out:
#                         SUMLEV  REGION  ...  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME                         ...
# Alabama Autauga County      50       3  ...     2.592270    -2.187333
#         Baldwin County      50       3  ...    20.317142    18.293499
#         Barbour County      50       3  ...    -3.978583   -10.543299
#         Bibb County         50       3  ...     0.754533     1.107861
#         Blount County       50       3  ...    -1.577232    -0.884411
#
# [5 rows x 98 columns]

# %%
row = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']
df.apply(lambda x: np.max(x[row]), axis=1)
# Out:
# STNAME   CTYNAME
# Alabama  Autauga County        55347.0
#          Baldwin County       203709.0
#          Barbour County        27341.0
#          Bibb County           22861.0
#          Blount County         57776.0
#                                 ...
# Wyoming  Sweetwater County     45162.0
#          Teton County          23125.0
#          Uinta County          21102.0
#          Washakie County        8545.0
#          Weston County          7234.0
# Length: 3142, dtype: float64

# %% [markdown]
# #                                                                                                          Group By

# %%
import pandas as pd
df=pd.DataFrame({'Animal':['Tiger','Tiger','Lion','Lion'], 'Max_speed':[370,380,200,240]})
df
# Out:
#   Animal  Max_speed
# 0  Tiger        370
# 1  Tiger        380
# 2   Lion        200
# 3   Lion        240

# %%
df.groupby('Animal').mean()
# Out:
#         Max_speed
# Animal
# Lion          220
# Tiger         375

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Data science/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 0      40       3         6  ...     1.383282     1.724718    0.712594
# 1      50       3         6  ...    -2.722002     2.592270   -2.187333
# 2      50       3         6  ...    22.727626    20.317142   18.293499
# 3      50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4      50       3         6  ...    -5.403729     0.754533    1.107861
#
# [5 rows x 100 columns]

# %%
# Selecting only whose SUMLEV values is 50.
df= df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 1         50       3         6  ...    -2.722002     2.592270   -2.187333
# 2         50       3         6  ...    22.727626    20.317142   18.293499
# 3         50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4         50       3         6  ...    -5.403729     0.754533    1.107861
# 5         50       3         6  ...    -1.402476    -1.577232   -0.884411
# ...      ...     ...       ...  ...          ...          ...         ...
# 3188      50       4         8  ...    -5.295460   -14.075283  -14.070195
# 3189      50       4         8  ...    21.160658    16.308671    1.520747
# 3190      50       4         8  ...    -7.521840   -14.740608  -12.606351
# 3191      50       4         8  ...    -2.250385   -18.020168    1.441961
# 3192      50       4         8  ...    12.372583     1.533635    6.935294
#
# [3142 rows x 100 columns]

# %%
# %%timeit -n 10
for state in df['STNAME'].unique():
  avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
  print('Countries in state ' + state + 'has an average population of ' + str(avg))
# Out:
# Countries in state Alabamahas an average population of 71339.34328358209
# Countries in state Alaskahas an average population of 24490.724137931036
# Countries in state Arizonahas an average population of 426134.4666666667
# Countries in state Arkansashas an average population of 38878.90666666667
# Countries in state Californiahas an average population of 642309.5862068966
# Countries in state Coloradohas an average population of 78581.1875
# Countries in state Connecticuthas an average population of 446762.125
# Countries in state Delawarehas an average population of 299311.3333333333
# Countries in state District of Columbiahas an average population of 601723.0
# Countries in state Floridahas an average population of 280616.5671641791
# Countries in state Georgiahas an average population of 60928.63522012578
# Countries in state Hawaiihas an average population of 272060.2
# Countries in state Idahohas an average population of 35626.86363636364
# ...

# %%
# %%timeit -n 10
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df = df.set_index('STNAME')

def fun(item):
  if item[0] <'M':      # if first letter of state name if m then return 0
    return 0
  if item[0] <'Q':      # if first letter of state name if q then return 1
    return 1
  return 2              # else return 2

for group,frame in df.groupby(fun):
  print('There are '+ str(len(frame))+ 'records in groups '+ str(group) + 'for processing')
# Out:
# There are 1177records in groups 0for processing
# There are 1134records in groups 1for processing
# There are 831records in groups 2for processing

# %%
# Loading census dataset.
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Data science/census.csv')
df = df[df['SUMLEV']==50]

# %% [markdown]
# **Dataframe.aggregate() function is used to apply some aggregation across one or more column.
# df.agg()**

# %%
df.groupby('STNAME').agg({'CENSUS2010POP':np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print (type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
print (type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby('STNAME').agg({'CENSUS2010POP':[np.average, np.sum]}).rename(columns = {'average': 'Average'})
# Out:
#                       CENSUS2010POP
#                             Average       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# Idaho                  35626.863636   1567582
# Illinois              125790.509804  12830632
# Indiana                70476.108696   6483802
# Iowa                   30771.262626   3046355
# Kansas                 27172.552381   2853118
# Kentucky               36161.391667   4339367
# ...

# %%
# Alternative method.
df.set_index('STNAME').groupby(level = 0).agg({'CENSUS2010POP':[np.average,np.sum]})
# Out:
#                       CENSUS2010POP
#                             average       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# Idaho                  35626.863636   1567582
# Illinois              125790.509804  12830632
# Indiana                70476.108696   6483802
# Iowa                   30771.262626   3046355
# Kansas                 27172.552381   2853118
# Kentucky               36161.391667   4339367
# ...

# %%
df.set_index('STNAME').groupby(level=0).agg({'POPESTIMATE2010':[np.average,np.sum],'POPESTIMATE2011':[np.average,np.sum]})
# Out:
#                      POPESTIMATE2010           POPESTIMATE2011
#                              average       sum         average       sum
# STNAME
# Alabama                 71420.313433   4785161    71658.328358   4801108
# Alaska                  24621.413793    714021    24921.379310    722720
# Arizona                427213.866667   6408208   431248.800000   6468732
# Arkansas                38965.253333   2922394    39180.506667   2938538
# California             643691.017241  37334079   650000.586207  37700034
# Colorado                78878.968750   5048254    79991.875000   5119480
# Connecticut            447464.625000   3579717   448719.875000   3589759
# Delaware               299930.333333    899791   302638.666667    907916
# District of Columbia   605126.000000    605126   620472.000000    620472
# Florida                281341.641791  18849890   285157.208955  19105533
# Georgia                 61090.905660   9713454    61712.452830   9812280
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# Georgia                  61090.905660          9812280
# Hawaii                  272796.000000          1378227
# ...

# %% [markdown]
# # Scales
# There are four types of scales.
#
#
# *   Ratio scale
# *   interval scale
#
#
# *   ordinal scale
# *   Nominal scale(categorical data)

# %%
import pandas as pd
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category').head() #df.astype() convert the data into categorical data.
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
grades = df['Grades'].astype('category', categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                             ordered=True)                    ## This nominal or categorical data is further converted into ordinal data by passing in an ordered flags set to True.
grades.head()                                                 ## In ordinal data order of values is important.

# %%
grades > 'C'

# %% [markdown]
# ## **Binning method**

# %%
s= pd.Series([168,180,174,190,170,185,179,181,175,169,182,177,180,171])
pd.cut(s,3)
# Out:
# 0     (167.978, 175.333]
# 1     (175.333, 182.667]
# 2     (167.978, 175.333]
# 3       (182.667, 190.0]
# 4     (167.978, 175.333]
# 5       (182.667, 190.0]
# 6     (175.333, 182.667]
# 7     (175.333, 182.667]
# 8     (167.978, 175.333]
# 9     (167.978, 175.333]
# 10    (175.333, 182.667]
# 11    (175.333, 182.667]
# 12    (175.333, 182.667]
# 13    (167.978, 175.333]
# dtype: category
# Categories (3, interval[float64]): [(167.978, 175.333] < (175.333, 182.667] < (182.667, 190.0]]

# %% [markdown]
# # Pivot Tables
# A pivot table is a way of summarizing data in a data frame for a particular purpose.It makes heavily use of aggreate functuon.
# A pivot table is itself a data frame, where the rows represent one variable that you're interested in, the columns another, and the cell's some aggregate value.
# ##    SYNTAX
#
# df.pivot_table(Data, values='   ', index='   ', columns='   ',aggfunc='    ',dropna= True, margins=True/False)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                "B": ["one", "one", "one", "two", "two",
                       "one", "one", "two", "two"],
                "C": ["small", "large", "large", "small",
                          "small", "large", "small", "small",
                       "large"],
                "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df.pivot_table(values='D', index=['A', 'B'],columns=['C'], aggfunc=np.sum)
# Out:
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %%
df.pivot_table(values='D', index=['A','B'], columns=['C'], aggfunc=np.sum,fill_value=0)
# Out:
# C        large  small
# A   B
# bar one      4      5
#     two      7      6
# foo one      4      1
#     two      0      6

# %%
df.pivot_table(values=['D', 'E'], index=['A', 'C'], aggfunc={'D': [np.sum, np.mean],'E': [np.sum,min, max, np.mean]})  #can pass multiple columns in aggregate function
# Out:
#                   D          E
#                mean   sum  max      mean  min   sum
# A   C
# bar large  5.500000  11.0  9.0  7.500000  6.0  15.0
#     small  5.500000  11.0  9.0  8.500000  8.0  17.0
# foo large  2.000000   4.0  5.0  4.500000  4.0   9.0
#     small  2.333333   7.0  6.0  4.333333  2.0  13.0

# %% [markdown]
# * **Pivot tables applied on real world dataset.**

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Data science/cars.csv')
df.head()
# Out:
#    YEAR        Make           Model        Size  ...  (g/km) RATING (km)  TIME (h)
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT  ...       0    NaN  100         7
# 1  2012      NISSAN            LEAF    MID-SIZE  ...       0    NaN  117         7
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT  ...       0    NaN  122         4
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT  ...       0    NaN  100         7
# 4  2013      NISSAN            LEAF    MID-SIZE  ...       0    NaN  117         7
#
# [5 rows x 17 columns]

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.sum])
# Out:
#        mean                         ...        sum
# Make    BMW CHEVROLET   FORD   KIA  ... MITSUBISHI NISSAN SMART   TESLA
# YEAR                                ...
# 2012    NaN       NaN    NaN   NaN  ...       49.0   80.0   NaN     NaN
# 2013    NaN       NaN  107.0   NaN  ...       49.0   80.0  70.0  1120.0
# 2014    NaN     104.0  107.0   NaN  ...       49.0   80.0  70.0   805.0
# 2015  125.0     104.0  107.0  81.0  ...       49.0   80.0  70.0  1924.0
# 2016  125.0     104.0  107.0  81.0  ...       49.0  160.0  70.0  4097.0
#
# [5 rows x 16 columns]

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.sum],fill_value=0)  # In place of null value put 0.
# Out:
#      mean                                ... sum
# Make  BMW CHEVROLET FORD KIA MITSUBISHI  ... KIA MITSUBISHI NISSAN SMART TESLA
# YEAR                                     ...
# 2012    0         0    0   0         49  ...   0         49     80     0     0
# 2013    0         0  107   0         49  ...   0         49     80    70  1120
# 2014    0       104  107   0         49  ...   0         49     80    70   805
# 2015  125       104  107  81         49  ...  81         49     80    70  1924
# 2016  125       104  107  81         49  ...  81         49    160    70  4097
#
# [5 rows x 16 columns]

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.sum],fill_value=0, margins = True)
# Out:
#      mean                                ...        sum
# Make  BMW CHEVROLET FORD KIA MITSUBISHI  ... MITSUBISHI NISSAN SMART TESLA    All
# YEAR                                     ...
# 2012    0         0    0   0         49  ...         49     80     0     0    129
# 2013    0         0  107   0         49  ...         49     80    70  1120   1426
# 2014    0       104  107   0         49  ...         49     80    70   805   1215
# 2015  125       104  107  81         49  ...         49     80    70  1924   2540
# 2016  125       104  107  81         49  ...         49    160    70  4097   4793
# All   125       104  107  81         49  ...        245    480   280  7946  10103
#
# [6 rows x 18 columns]

# %% [markdown]
# #                                                    Date Functionality in pandas
# Pandas has four main time related class.
#
# 1.   Timestamp
# 2.   Datetime index
# 3.   Period
# 4.   Period index.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Timestamp
# Timestamp represents a single timestamp and associates values with points in time.
# Timestamp is interchangeable with Python's datetime in most cases

# %%
pd.Timestamp('24/05/2019 09:30PM')
# Out:
# Timestamp('2019-05-24 21:30:00')

# %% [markdown]
# # Period
# Suppose we weren't interested in a specific point in time, and instead wanted a span of time. This is where Period comes into play.
# Period represents a single time span, such as a specific day or month.

# %%
pd.Period('05/2019')
# Out:
# Period('2019-05', 'M')

# %%
pd.Period('03/05/2019')
# Out:
# Period('2019-03-05', 'D')

# %% [markdown]
# # DateTime index
# The index of a timestamp is DatetimeIndex and has a value associated with it.

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('05/03/2019'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
t1
# Out:
# 2019-05-03    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Period index
# Index of period is called is Period index.

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09-05'), pd.Period('2016-10-06'), pd.Period('2016-11-07')])
t2
# Out:
# 2016-09-05    d
# 2016-10-06    e
# 2016-11-07    f
# Freq: D, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# # Converting to Datetime

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   35  37
# Aug 29, 2014  15  72
# 2015-06-26    40  99
# 7/12/16       33  92

# %%
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2013-06-02  35  37
# 2014-08-29  15  72
# 2015-06-26  40  99
# 2016-07-12  33  92

# %% [markdown]
# # Timedeltas

# %%
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')
